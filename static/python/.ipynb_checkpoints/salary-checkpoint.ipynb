# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Stroe CSV into DataFrame
salary_file="../../resources/survey_results_public.csv"
#this raw data file is too large to push to the repo so it is removed before pushing to the repo
salary_df = pd.read_csv(salary_file)
salary_df.head()
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# ...

# %%
salary_df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %%
salary_df['FormalEducation']
# Out:
# 0                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                         Associate degree
# 3                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4        Some college/university study without earning ...
# 5                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6        Some college/university study without earning ...
# 7                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8        Some college/university study without earning ...
# 9                 Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 12       Some college/university study without earning ...
# 13                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 14       Secondary school (e.g. American high school, G...
# 15             Master’s degree (MA, MS, M.Eng., MBA, etc.)
# ...

# %%
salary_df_filteredcountry = salary_df[salary_df['Country'] == 'United States']
salary_df_filtered = salary_df_filteredcountry[(salary_df_filteredcountry['Gender'] == 'Female')|(salary_df_filteredcountry['Gender'] == 'Male')]
salary_df_filtered.head()
# Out:
#     Respondent Hobby OpenSource        Country Student          Employment  \
# 3            5    No         No  United States      No  Employed full-time
# 6            9   Yes        Yes  United States      No  Employed full-time
# 8           11   Yes        Yes  United States      No  Employed full-time
# 21          34   Yes         No  United States      No  Employed full-time
# 27          44    No         No  United States      No  Employed full-time
#
#                                       FormalEducation  \
# 3            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6   Some college/university study without earning ...
# 8   Some college/university study without earning ...
# 21           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 27           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                        UndergradMajor  \
# 3   Computer science, computer engineering, or sof...
# 6   Computer science, computer engineering, or sof...
# ...

# %%
salary_df_filtered_new = salary_df_filtered[['Country', 'Age', 'Gender','Salary','FormalEducation']].copy()
salary_df_filtered_new.head()
# Out:
#           Country                Age Gender  Salary  \
# 3   United States  35 - 44 years old   Male     NaN
# 6   United States  18 - 24 years old   Male  120000
# 8   United States  35 - 44 years old   Male  250000
# 21  United States  45 - 54 years old   Male     NaN
# 27  United States  25 - 34 years old   Male   75000
#
#                                       FormalEducation
# 3            Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6   Some college/university study without earning ...
# 8   Some college/university study without earning ...
# 21           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 27           Bachelor’s degree (BA, BS, B.Eng., etc.)

# %%
salary_df_filtered_new.dropna(inplace = True) 
salary_df_filtered_new.head()
# Out:
#           Country                Age  Gender  Salary  \
# 6   United States  18 - 24 years old    Male  120000
# 8   United States  35 - 44 years old    Male  250000
# 27  United States  25 - 34 years old    Male   75000
# 32  United States  18 - 24 years old  Female   44000
# 33  United States  25 - 34 years old  Female   60000
#
#                                       FormalEducation
# 6   Some college/university study without earning ...
# 8   Some college/university study without earning ...
# 27           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 33           Bachelor’s degree (BA, BS, B.Eng., etc.)

# %%
salary_df_filtered_new.dtypes
# Out:
# Country            object
# Age                object
# Gender             object
# Salary             object
# FormalEducation    object
# dtype: object

# %%
salary_df_filtered_new["Salary"]= salary_df_filtered_new["Salary"].replace(",", "",regex=True)

# %%
salary_df_filtered_new[salary_df_filtered_new["Salary"]=="112,000.00"]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, Salary, FormalEducation]
# Index: []

# %%
salary_df_filtered_new['Salary']= salary_df_filtered_new['Salary'].astype(float)
salary_df_filtered_new.dtypes
# Out:
# Country             object
# Age                 object
# Gender              object
# Salary             float64
# FormalEducation     object
# dtype: object

# %%
#Save salary data
salary_df_filtered_new.to_csv("../../resources/cleaneddata/salarydata.csv")
salary_df_filtered_new.to_json("../../static/dataset/salary_data.JSON")

# %%
salary_df_filtered_new['Salary'].median()
# Out:
# 95000.0

# %%
salary_agegendereducation_median = salary_df_filtered_new.groupby(["Gender","Age","FormalEducation"])['Salary'].median().to_frame().reset_index()

salary_agegendereducation_median.head(10)
# Out:
#    Gender                Age  \
# 0  Female  18 - 24 years old
# 1  Female  18 - 24 years old
# 2  Female  18 - 24 years old
# 3  Female  18 - 24 years old
# 4  Female  18 - 24 years old
# 5  Female  25 - 34 years old
# 6  Female  25 - 34 years old
# 7  Female  25 - 34 years old
# 8  Female  25 - 34 years old
# 9  Female  25 - 34 years old
#
#                                      FormalEducation   Salary
# 0                                   Associate degree  42000.0
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)  70000.0
# 2        Master’s degree (MA, MS, M.Eng., MBA, etc.)  90000.0
# 3  Secondary school (e.g. American high school, G...  12650.0
# 4  Some college/university study without earning ...  38595.0
# 5                                   Associate degree  70000.0
# 6           Bachelor’s degree (BA, BS, B.Eng., etc.)  85000.0
# 7        Master’s degree (MA, MS, M.Eng., MBA, etc.)  85000.0
# 8          Other doctoral degree (Ph.D, Ed.D., etc.)  75000.0
# ...

# %%
#Save salary, gender, age, and education data
salary_agegendereducation_median.to_csv("../../resources/cleaneddata/salary_agegenedu_data.csv")
salary_agegendereducation_median.to_json("../../static/dataset/salary_agegenedu_data.JSON")

# %%
salary_education_median = salary_df_filtered_new.groupby(["FormalEducation"])['Salary'].median().to_frame().reset_index()

salary_education_median.head(10)
# Out:
#                                      FormalEducation     Salary
# 0                                   Associate degree   71000.00
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)   95000.00
# 2             I never completed any formal education   80000.00
# 3        Master’s degree (MA, MS, M.Eng., MBA, etc.)  110000.00
# 4          Other doctoral degree (Ph.D, Ed.D., etc.)  120000.00
# 5                          Primary/elementary school       5.25
# 6                 Professional degree (JD, MD, etc.)   93750.00
# 7  Secondary school (e.g. American high school, G...   50000.00
# 8  Some college/university study without earning ...   85000.00

# %%
#Save salar and education data
salary_education_median.to_csv("../../resources/cleaneddata/salary_edu_data.csv")
salary_education_median.to_json("../../static/dataset/salary_edu_data.JSON")

# %%
salary_age_median = salary_df_filtered_new.groupby(["Age"])['Salary'].median().to_frame().reset_index()

salary_age_median.head(10)
# Out:
#                   Age    Salary
# 0   18 - 24 years old   65000.0
# 1   25 - 34 years old   91000.0
# 2   35 - 44 years old  115000.0
# 3   45 - 54 years old  120000.0
# 4   55 - 64 years old  120000.0
# 5   65 years or older  100000.0
# 6  Under 18 years old       0.0

# %%
#Save age and salary data
salary_age_median.to_csv("../../resources/cleaneddata/salary_age_data.csv")
salary_age_median.to_json("../../static/dataset/salary_age_data.JSON")

# %%
salary_gender_median = salary_df_filtered_new.groupby(["Gender"])['Salary'].median().to_frame().reset_index()

salary_gender_median.head(10)
# Out:
#    Gender   Salary
# 0  Female  82000.0
# 1    Male  97000.0

# %%
#Save gender and salary data
salary_gender_median.to_csv("../../resources/cleaneddata/salary_gender_data.csv")
salary_gender_median.to_json("../../static/dataset/salary_gender_data.JSON")

# %%
salary_genderage_median = salary_df_filtered_new.groupby(["Gender","Age"])['Salary'].median().to_frame().reset_index()

salary_genderage_median.head(10)
# Out:
#    Gender                Age    Salary
# 0  Female  18 - 24 years old   65000.0
# 1  Female  25 - 34 years old   84000.0
# 2  Female  35 - 44 years old   93000.0
# 3  Female  45 - 54 years old  104000.0
# 4  Female  55 - 64 years old   86500.0
# 5    Male  18 - 24 years old   65000.0
# 6    Male  25 - 34 years old   92500.0
# 7    Male  35 - 44 years old  116000.0
# 8    Male  45 - 54 years old  123000.0
# 9    Male  55 - 64 years old  124000.0

# %%
salary_genderedu_median = salary_df_filtered_new.groupby(["Gender","FormalEducation"])['Salary'].median().to_frame().reset_index()

salary_genderedu_median.head(10)
# Out:
#    Gender                                    FormalEducation   Salary
# 0  Female                                   Associate degree  55000.0
# 1  Female           Bachelor’s degree (BA, BS, B.Eng., etc.)  85000.0
# 2  Female             I never completed any formal education  15448.5
# 3  Female        Master’s degree (MA, MS, M.Eng., MBA, etc.)  90000.0
# 4  Female          Other doctoral degree (Ph.D, Ed.D., etc.)  85000.0
# 5  Female                 Professional degree (JD, MD, etc.)  95000.0
# 6  Female  Secondary school (e.g. American high school, G...  20000.0
# 7  Female  Some college/university study without earning ...  66000.0
# 8    Male                                   Associate degree  72618.5
# 9    Male           Bachelor’s degree (BA, BS, B.Eng., etc.)  97000.0

# %%
salary_ageedu_median = salary_df_filtered_new.groupby(["Age","FormalEducation"])['Salary'].median().to_frame().reset_index()

salary_ageedu_median.head(10)
# Out:
#                  Age                                    FormalEducation  \
# 0  18 - 24 years old                                   Associate degree
# 1  18 - 24 years old           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  18 - 24 years old             I never completed any formal education
# 3  18 - 24 years old        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4  18 - 24 years old          Other doctoral degree (Ph.D, Ed.D., etc.)
# 5  18 - 24 years old                          Primary/elementary school
# 6  18 - 24 years old  Secondary school (e.g. American high school, G...
# 7  18 - 24 years old  Some college/university study without earning ...
# 8  25 - 34 years old                                   Associate degree
# 9  25 - 34 years old           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#     Salary
# 0  35000.0
# 1  71000.0
# 2    220.0
# 3  80000.0
# 4   1143.0
# 5   4000.0
# 6  15000.0
# 7  35000.0
# 8  70000.0
# 9  90000.0

# %%
salary_education_median["Gender"]=["All"] * len(salary_education_median)
salary_education_median["Age"]=["All"] * len(salary_education_median)

salary_age_median["Gender"]=["All"] * len(salary_age_median)
salary_age_median["FormalEducation"]=["All"] * len(salary_age_median)

salary_gender_median["Age"]=["All"] * len(salary_gender_median)
salary_gender_median["FormalEducation"]=["All"] * len(salary_gender_median)

salary_ageedu_median["Gender"]=["All"] * len(salary_ageedu_median)

salary_genderedu_median["Age"]=["All"] * len(salary_genderedu_median)

salary_genderage_median["FormalEducation"]=["All"] * len(salary_genderage_median)

# %%
pd_combined = pd.concat([salary_agegendereducation_median, salary_gender_median, salary_age_median, salary_education_median, salary_ageedu_median, salary_genderedu_median, salary_genderage_median], ignore_index=True, sort=True)
pd_combined.head()
# Out:
#                  Age                                    FormalEducation  \
# 0  18 - 24 years old                                   Associate degree
# 1  18 - 24 years old           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  18 - 24 years old        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  18 - 24 years old  Secondary school (e.g. American high school, G...
# 4  18 - 24 years old  Some college/university study without earning ...
#
#    Gender   Salary
# 0  Female  42000.0
# 1  Female  70000.0
# 2  Female  90000.0
# 3  Female  12650.0
# 4  Female  38595.0

# %%
pd_combined
# Out:
#                     Age                                    FormalEducation  \
# 0     18 - 24 years old                                   Associate degree
# 1     18 - 24 years old           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2     18 - 24 years old        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3     18 - 24 years old  Secondary school (e.g. American high school, G...
# 4     18 - 24 years old  Some college/university study without earning ...
# 5     25 - 34 years old                                   Associate degree
# 6     25 - 34 years old           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7     25 - 34 years old        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 8     25 - 34 years old          Other doctoral degree (Ph.D, Ed.D., etc.)
# 9     25 - 34 years old                 Professional degree (JD, MD, etc.)
# 10    25 - 34 years old  Secondary school (e.g. American high school, G...
# ...

# %%
#Save all calculated salary data
pd_combined.to_csv("../../resources/cleaneddata/salary_median_data.csv")
pd_combined.to_json("../../static/dataset/salary_median_data.JSON")
